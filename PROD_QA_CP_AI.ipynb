# %% [markdown]
# <a href="https://colab.research.google.com/github/CryptoPrism-io/CryptoPrism-DB/blob/main/PROD_QA_CP_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title pip

required_packages = [
    "pandas",
    "numpy",
    "sqlalchemy",
    "psycopg2-binary",
    "python-dotenv",
    "mysql-connector-python",
    "python-telegram-bot==13.15"
]

# Write to requirements.txt
with open("requirements.txt", "w") as f:
    f.write("\n".join(required_packages))

try:
    import google.colab  # Checks if running in Colab
    print("Running in Colab: Installing dependencies...")
    # !pip install -r requirements.txt
except ImportError:
    print("Running outside Colab (e.g., GitHub Actions), skipping installation.")
# Out:
# Running in Colab: Installing dependencies...
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (2.0.37)
# Collecting psycopg2-binary (from -r requirements.txt (line 4))
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting python-dotenv (from -r requirements.txt (line 5))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting mysql-connector-python (from -r requirements.txt (line 6))
#   Downloading mysql_connector_python-9.2.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting python-telegram-bot==13.15 (from -r requirements.txt (line 7))
#   Downloading python_telegram_bot-13.15-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from python-telegram-bot==13.15->-r requirements.txt (line 7)) (2024.12.14)
# Collecting tornado==6.1 (from python-telegram-bot==13.15->-r requirements.txt (line 7))
#   Downloading tornado-6.1.tar.gz (497 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.4/497.4 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting APScheduler==3.6.3 (from python-telegram-bot==13.15->-r requirements.txt (line 7))
#   Downloading APScheduler-3.6.3-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pytz>=2018.6 in /usr/local/lib/python3.11/dist-packages (from python-telegram-bot==13.15->-r requirements.txt (line 7)) (2024.2)
# Collecting cachetools==4.2.2 (from python-telegram-bot==13.15->-r requirements.txt (line 7))
#   Downloading cachetools-4.2.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools>=0.7 in /usr/local/lib/python3.11/dist-packages (from APScheduler==3.6.3->python-telegram-bot==13.15->-r requirements.txt (line 7)) (75.1.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from APScheduler==3.6.3->python-telegram-bot==13.15->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.11/dist-packages (from APScheduler==3.6.3->python-telegram-bot==13.15->-r requirements.txt (line 7)) (5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->-r requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->-r requirements.txt (line 3)) (4.12.2)
# Downloading python_telegram_bot-13.15-py3-none-any.whl (519 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 18.0 MB/s eta 0:00:00
# Downloading APScheduler-3.6.3-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 3.0 MB/s eta 0:00:00
# Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 40.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading mysql_connector_python-9.2.0-cp311-cp311-manylinux_2_28_x86_64.whl (34.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 14.2 MB/s eta 0:00:00
# Building wheels for collected packages: tornado
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-6.1-cp311-cp311-linux_x86_64.whl size=422002 sha256=a39b72a57a0fb49475263c8808d7a5025e288a98b3f854568e832f489e6132f8
#   Stored in directory: /root/.cache/pip/wheels/f2/59/06/a9c85c7b17ec0fc9b1e2ae0c59e3d39255d5c0a38492e33fea
# Successfully built tornado
# Installing collected packages: tornado, python-dotenv, psycopg2-binary, mysql-connector-python, cachetools, APScheduler, python-telegram-bot
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.3
#     Uninstalling tornado-6.3.3:
#       Successfully uninstalled tornado-6.3.3
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.5.1
#     Uninstalling cachetools-5.5.1:
#       Successfully uninstalled cachetools-5.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado==6.3.3, but you have tornado 6.1 which is incompatible.
# bokeh 3.6.2 requires tornado>=6.2, but you have tornado 6.1 which is incompatible.
# Successfully installed APScheduler-3.6.3 cachetools-4.2.2 mysql-connector-python-9.2.0 psycopg2-binary-2.9.10 python-dotenv-1.0.1 python-telegram-bot-13.15 tornado-6.1

# %%
#@title .env
# Create the .env file and write the variables to it
env_content = """
DB_HOST="34.55.195.199"
DB_USER="yogass09"
DB_PASSWORD="jaimaakamakhya"
DB_PORT="5432"
GEMINI_API_KEY="AIzaSyAuji6f62tQmNqmLRNOSt1pw5vg2AafzGY"
"""

# Write the content to a file called .env
with open('.env', 'w') as f:
    f.write(env_content)

# %%
#@title .env [load]
import os
import logging
from dotenv import load_dotenv

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# Load .env file ONLY if running locally (not in GitHub Actions)
if not os.getenv("GITHUB_ACTIONS"):
    env_file = ".env"
    if os.path.exists(env_file):
        load_dotenv()
        logger.info("✅ .env file loaded successfully.")
    else:
        logger.error("❌ .env file is missing! Please create one for local testing.")
else:
    logger.info("🔹 Running in GitHub Actions: Using GitHub Secrets.")

# Fetch credentials (Works for both local and GitHub Actions)
DB_HOST = os.getenv("DB_HOST")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_PORT = os.getenv("DB_PORT", "5432")  # Default to 5432 if not set
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Validate required environment variables
missing_vars = [var for var in ["DB_HOST", "DB_USER", "DB_PASSWORD", "GEMINI_API_KEY"] if not globals()[var]]
if missing_vars:
    logger.error(f"❌ Missing environment variables: {', '.join(missing_vars)}")
    raise SystemExit("❌ Terminating: Missing required credentials.")

# Log only necessary info (DO NOT log DB_PASSWORD for security)
logger.info(f"✅ Database Configuration Loaded: DB_HOST={DB_HOST}, DB_PORT={DB_PORT}")

# %%
# @title Delete duplicates
import os
from sqlalchemy import create_engine, text
from typing import Dict
import logging
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Fetch database credentials
DB_HOST = os.getenv("DB_HOST")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_PORT = os.getenv("DB_PORT", "5432")

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def delete_duplicates(db_names):
    results = {}

    for db_name in db_names:
        try:
            engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{db_name}',
                                   isolation_level="AUTOCOMMIT")
            logger.info(f"Processing database: {db_name}")
            results[db_name] = {}

            with engine.connect() as conn:
                # Fetch all table names
                table_names_query = text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';")
                table_names = [row[0] for row in conn.execute(table_names_query)]

                for table_name in table_names:
                    try:
                        # Check if 'slug' and 'timestamp' columns exist
                        column_check_query = text(f"""
                            SELECT column_name FROM information_schema.columns
                            WHERE table_name = '{table_name}'
                            AND column_name IN ('slug', 'timestamp');
                        """)
                        existing_columns = {row[0] for row in conn.execute(column_check_query)}

                        if 'slug' not in existing_columns or 'timestamp' not in existing_columns:
                            logger.info(f"Skipping table '{table_name}' in DB '{db_name}': Missing required columns.")
                            continue

                        # DELETE query based only on 'slug' and 'timestamp'
                        delete_query = text(f"""
                            DELETE FROM public."{table_name}" AS t1
                            USING (
                                SELECT ctid FROM (
                                    SELECT ctid, ROW_NUMBER() OVER (PARTITION BY slug, timestamp ORDER BY ctid) AS row_num
                                    FROM public."{table_name}"
                                ) AS subquery
                                WHERE row_num > 1
                            ) AS t2
                            WHERE t1.ctid = t2.ctid;
                        """)

                        # Execute delete query
                        result = conn.execute(delete_query)
                        deleted_rows = result.rowcount
                        results[db_name][table_name] = deleted_rows
                        logger.info(f"Deleted {deleted_rows} duplicate rows from '{table_name}' in DB '{db_name}'.")

                        # Run VACUUM ANALYZE
                        conn.execute(text(f"VACUUM ANALYZE public.\"{table_name}\";"))
                        logger.info(f"Vacuumed '{table_name}' in DB '{db_name}'.")

                    except Exception as e:
                        logger.error(f"Error processing table '{table_name}' in DB '{db_name}': {e}")
                        conn.execute(text("ROLLBACK;"))  # ROLLBACK transaction on error

                logger.info("=" * 50)

        except Exception as e:
            logger.error(f"Error connecting to database '{db_name}': {e}")

    return results

# List of databases to process
db_names = ['cp_ai']

# Run the function
delete_results = delete_duplicates(db_names)
identify_and_delete_duplicate_timestamps_multiple_dbs_results = delete_results
identify_and_delete_duplicate_timestamps_multiple_dbs_results
# Out:
# {'cp_ai': {'ohlcv_1h_250_coins': 0,
#   'FE_TVV': 0,
#   'FE_TVV_SIGNALS': 0,
#   'FE_PCT_CHANGE': 0,
#   'FE_MOMENTUM': 0,
#   'FE_MOMENTUM_SIGNALS': 0,
#   'FE_OSCILLATOR': 0,
#   'FE_OSCILLATORS_SIGNALS': 0,
#   'FE_RATIOS': 0,
#   'FE_RATIOS_SIGNALS': 0,
#   'FE_DMV_ALL': 0},
#  'dbcp': {'1K_coins_ohlcv': 0,
#   'FE_METRICS': 0,
#   'FE_METRICS_SIGNAL': 0,
#   'FE_TVV': 0,
#   'FE_TVV_SIGNALS': 0,
#   'FE_PCT_CHANGE': 0,
#   '108_1K_coins_ohlcv': 0,
#   'FE_MOMENTUM': 0,
#   'FE_MOMENTUM_SIGNALS': 0,
#   'FE_OSCILLATOR': 0,
#   'FE_OSCILLATORS_SIGNALS': 0,
#   'FE_RATIOS': 0,
#   'FE_RATIOS_SIGNALS': 0,
#   '1K_coins_ohlcv_backup': 0,
#   'FE_DMV_ALL': 0},
#  'cp_backtest': {'FE_TVV': 0,
#   'FE_RATIOS': 0,
#   'FE_RATIOS_SIGNALS': 0,
#   'FE_TVV_SIGNALS': 0,
#   'FE_PCT_CHANGE': 0,
#   'FE_MOMENTUM': 0,
#   'FE_MOMENTUM_SIGNALS': 0,
#   'FE_OSCILLATOR': 0,
#   'FE_OSCILLATORS_SIGNALS': 0},
#  'cp_backtest_h': {'FE_TVV': 0,
#   'FE_TVV_SIGNALS': 0,
#   'FE_PCT_CHANGE': 0,
#   'FE_OSCILLATOR': 0,
#   'FE_MOMENTUM': 0,
#   'FE_MOMENTUM_SIGNALS': 0,
#   'FE_OSCILLATORS_SIGNALS': 0,
#   'FE_RATIOS': 0,
#   'FE_RATIOS_SIGNALS': 0}}

# %%
#@title cp_ai QA analysis for SQL DB
import os
import json
import logging
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
from datetime import datetime
from dateutil.parser import parse

# Load environment variables
load_dotenv()

# Fetch database credentials
DB_HOST = os.getenv("DB_HOST")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_PORT = os.getenv("DB_PORT", "5432")  # Default to 5432 if not set

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

def classify_null_ratio(null_ratio):
    """Classifies the null ratio into risk levels."""
    if null_ratio is None:
        return "UNKNOWN"
    elif null_ratio < 0.2:
        return "LOW"
    elif 0.2 <= null_ratio < 0.49:
        return "MEDIUM"
    elif 0.49 <= null_ratio < 0.89:
        return "HIGH"
    else:
        return "CRITICAL"

def validate_timestamps(table_name, first_timestamp, last_timestamp):
    """Validates timestamps based on table name rules and checks for NULL values."""
    if not first_timestamp or not last_timestamp:
        return "WARNING: First and/or Last timestamp is NULL"

    try:
        first_dt = parse(first_timestamp)
        last_dt = parse(last_timestamp)

        if table_name.startswith("FE_"):
            if first_dt != last_dt:
                return "CRITICAL ERROR: FE Table timestamps must match"
        else:
            if (last_dt - first_dt).days < 4:
                return "CRITICAL ERROR: Non-FE Table timestamps must have at least a 4-day gap"

    except Exception as e:
        return f"ERROR: Invalid timestamp format ({e})"

    return "VALID"

def analyze_database(db_name):
    """Analyzes table schemas, row counts, null stats, timestamps, and duplicates in a PostgreSQL database."""
    logger.info(f"Processing database: {db_name}")

    try:
        engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{db_name}')
    except Exception as e:
        logger.error(f"Database connection failed for {db_name}: {e}")
        return {}

    results = {}

    try:
        with engine.connect() as conn:
            # Fetch all table names
            table_names_query = text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';")
            table_names = [row[0] for row in conn.execute(table_names_query)]

            for table_name in table_names:
                try:
                    # Fetch column names and data types
                    columns_query = text(f"""
                        SELECT column_name, data_type FROM information_schema.columns
                        WHERE table_name = '{table_name}' AND table_schema = 'public';
                    """)
                    columns_df = pd.read_sql_query(columns_query, conn)

                    # Fetch total row count
                    row_count_query = text(f'SELECT COUNT(*) FROM public."{table_name}";')
                    row_count = conn.execute(row_count_query).scalar()

                    # Handle timestamps
                    timestamp_columns = columns_df[columns_df["data_type"].str.contains("timestamp", case=False)]["column_name"].tolist()
                    first_timestamp, last_timestamp, timestamp_status = None, None, "VALID"

                    if timestamp_columns:
                        timestamp_col = timestamp_columns[0]
                        first_query = text(f'SELECT "{timestamp_col}" FROM public."{table_name}" ORDER BY "{timestamp_col}" ASC LIMIT 1;')
                        last_query = text(f'SELECT "{timestamp_col}" FROM public."{table_name}" ORDER BY "{timestamp_col}" DESC LIMIT 1;')

                        first_timestamp = conn.execute(first_query).scalar()
                        last_timestamp = conn.execute(last_query).scalar()

                        first_timestamp = str(first_timestamp) if first_timestamp else None
                        last_timestamp = str(last_timestamp) if last_timestamp else None

                        timestamp_status = validate_timestamps(table_name, first_timestamp, last_timestamp)

                    # Fetch NULL statistics for each column
                    column_stats = {}
                    for _, row in columns_df.iterrows():
                        column_name = row['column_name']

                        null_count_query = text(f'SELECT COUNT(*) FROM public."{table_name}" WHERE "{column_name}" IS NULL;')
                        null_count = conn.execute(null_count_query).scalar()

                        non_null_count = row_count - null_count
                        null_ratio = round(null_count / row_count, 4) if row_count > 0 else None
                        risk_classification = classify_null_ratio(null_ratio)

                        column_stats[column_name] = {
                            "dataType": row['data_type'],
                            "null_count": null_count,
                            "non_null_count": non_null_count,
                            "total_rows": row_count,
                            "null_ratio": null_ratio,
                            "risk_classification": risk_classification
                        }

                    # Check for duplicate slug + timestamp
                    duplicate_count = None
                    duplicate_status = "VALID"

                    column_check_query = text(f"""
                        SELECT column_name FROM information_schema.columns
                        WHERE table_name = '{table_name}' AND column_name IN ('slug', 'timestamp');
                    """)
                    existing_columns = {row[0] for row in conn.execute(column_check_query)}

                    if 'slug' in existing_columns and 'timestamp' in existing_columns:
                        duplicate_query = text(f"""
                            SELECT COUNT(*) FROM (
                                SELECT slug, timestamp, ROW_NUMBER() OVER (PARTITION BY slug, timestamp ORDER BY id DESC) as rn
                                FROM public."{table_name}"
                            ) t WHERE rn > 1;
                        """)
                        duplicate_count = conn.execute(duplicate_query).scalar()

                        if duplicate_count > 0:
                            duplicate_status = "CRITICAL ERROR: Duplicate rows found"

                    # Store results
                    results[table_name] = {
                        "columns": column_stats,
                        "column_count": len(column_stats),
                        "total_rows": row_count,
                        "first_timestamp": first_timestamp,
                        "last_timestamp": last_timestamp,
                        "timestamp_status": timestamp_status,
                        "duplicate_count": duplicate_count,
                        "duplicate_status": duplicate_status
                    }

                    logger.info(f"Processed table: {table_name} ({len(column_stats)} columns, {duplicate_count} duplicates)")

                except Exception as e:
                    logger.error(f"Error processing table '{table_name}' in DB '{db_name}': {e}")

    except Exception as e:
        logger.error(f"Error connecting to database '{db_name}': {e}")

    return results

# List of databases to analyze
db_names = ['cp_ai']

# Run analysis for each database
database_analysis_results = {db: analyze_database(db) for db in db_names}

# Save results to JSON
output_file = "database_analysis_results.json"
try:
    with open(output_file, "w") as f:
        json.dump(database_analysis_results, f, indent=4)
    logger.info(f"Analysis completed. Results saved to {output_file}")
except Exception as e:
    logger.error(f"Failed to save results to JSON: {e}")

# Print summary
print(json.dumps(database_analysis_results, indent=4))
# Out:
# {
#     "cp_ai": {
#         "ohlcv_1h_250_coins": {
#             "columns": {
#                 "id": {
#                     "dataType": "integer",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "symbol": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "open": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "high": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "low": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "close": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "volume": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "market_cap": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 25200,
#                     "total_rows": 25200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 11,
#             "total_rows": 25200,
#             "first_timestamp": "2025-02-26 00:59:59+00:00",
#             "last_timestamp": "2025-03-03 05:59:59+00:00",
#             "timestamp_status": "VALID",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "crypto_listings_latest": {
#             "columns": {
#                 "id": {
#                     "dataType": "integer",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "symbol": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "cmc_rank": {
#                     "dataType": "integer",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "market_pair_count": {
#                     "dataType": "integer",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "circulating_supply": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "self_reported_circulating_supply": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "total_supply": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "max_supply": {
#                     "dataType": "double precision",
#                     "null_count": 137,
#                     "non_null_count": 112,
#                     "total_rows": 249,
#                     "null_ratio": 0.5502,
#                     "risk_classification": "HIGH"
#                 },
#                 "is_active": {
#                     "dataType": "integer",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "last_updated": {
#                     "dataType": "date",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "date_added": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "ref_currency": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "price": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "volume24h": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "market_cap": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "percent_change1h": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "percent_change24h": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "percent_change7d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "percent_change30d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "percent_change60d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "percent_change90d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "fully_dillutted_market_cap": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "market_cap_by_total_supply": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "dominance": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "turnover": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "ytd_price_change_percentage": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "percent_change1y": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 249,
#                     "total_rows": 249,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "tvl": {
#                     "dataType": "double precision",
#                     "null_count": 231,
#                     "non_null_count": 18,
#                     "total_rows": 249,
#                     "null_ratio": 0.9277,
#                     "risk_classification": "CRITICAL"
#                 }
#             },
#             "column_count": 30,
#             "total_rows": 249,
#             "first_timestamp": null,
#             "last_timestamp": null,
#             "timestamp_status": "VALID",
#             "duplicate_count": null,
#             "duplicate_status": "VALID"
#         },
#         "FE_TVV": {
#             "columns": {
#                 "id": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "open": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "high": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "low": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "close": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "volume": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "market_cap": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "obv": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_tvv_obv_1d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "SMA9": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "SMA18": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "EMA9": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "EMA18": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "SMA21": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "SMA108": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "EMA21": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "EMA108": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "prev_close": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "tr1": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "tr2": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "tr3": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "TR": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "ATR": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Keltner_Upper": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Keltner_Lower": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Donchian_Upper": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Donchian_Lower": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "typical_price": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "cum_price_volume": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "cum_volume": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "VWAP": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "ADL": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "cum_adl": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "CMF": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 37,
#             "total_rows": 200,
#             "first_timestamp": "2025-03-03 05:59:59+00:00",
#             "last_timestamp": "2025-03-03 05:59:59+00:00",
#             "timestamp_status": "VALID",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "FE_TVV_SIGNALS": {
#             "columns": {
#                 "m_tvv_cmf": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "id": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_tvv_obv_1d_binary": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_sma9_18": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_ema9_18": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_sma21_108": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_ema21_108": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 9,
#             "total_rows": 200,
#             "first_timestamp": "2025-03-03 05:59:59+00:00",
#             "last_timestamp": "2025-03-03 05:59:59+00:00",
#             "timestamp_status": "VALID",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "FE_PCT_CHANGE": {
#             "columns": {
#                 "id": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_pct_1d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_pct_cum_ret": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_pct_var": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_pct_cvar": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_pct_vol_1d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 9,
#             "total_rows": 200,
#             "first_timestamp": "2025-03-03 05:59:59+00:00",
#             "last_timestamp": "2025-03-03 05:59:59+00:00",
#             "timestamp_status": "VALID",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "FE_MOMENTUM": {
#             "columns": {
#                 "id": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_pct_1d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_rsi_9": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_rsi_18": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_rsi_27": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_rsi_54": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_rsi_108": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "sma_14": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "sma_14_normalized": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_roc": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_williams_%": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_smi": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_cmo": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_mom": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_tsi": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 18,
#             "total_rows": 200,
#             "first_timestamp": "2025-03-03 05:59:59+00:00",
#             "last_timestamp": "2025-03-03 05:59:59+00:00",
#             "timestamp_status": "VALID",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "FE_MOMENTUM_SIGNALS": {
#             "columns": {
#                 "id": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_roc_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_williams_%_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_smi_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_cmo_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_mom_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 9,
#             "total_rows": 200,
#             "first_timestamp": "2025-03-03 05:59:59+00:00",
#             "last_timestamp": "2025-03-03 05:59:59+00:00",
#             "timestamp_status": "VALID",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "FE_OSCILLATOR": {
#             "columns": {
#                 "id": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "open": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "high": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "low": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "close": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "volume": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "market_cap": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_pct_1d": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_pct_cum_ret": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "EMA_12": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "EMA_26": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "MACD": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Signal": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "TP": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "SMA_TP": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "MAD": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "CCI": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "TR": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "+DM": {
#                     "dataType": "boolean",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "-DM": {
#                     "dataType": "boolean",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Smoothed_TR": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Smoothed_+DM": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Smoothed_-DM": {
# ...
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_sharpe_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_sortino_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_teynor_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_common_sense_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_information_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_win_loss_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_rat_win_rate_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_rat_ror_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_rat_pain_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 199,
#                     "total_rows": 199,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 15,
#             "total_rows": 199,
#             "first_timestamp": "2025-03-03 05:59:59+00:00",
#             "last_timestamp": "2025-03-03 05:59:59+00:00",
#             "timestamp_status": "VALID",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "FE_DMV_ALL": {
#             "columns": {
#                 "id": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "name": {
#                     "dataType": "text",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "timestamp": {
#                     "dataType": "timestamp with time zone",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "d_rat_beta_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "d_rat_pain_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_ema21_108": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_ema9_18": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_sma21_108": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "d_tvv_sma9_18": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_cmo_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_mom_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_roc_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_smi_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_mom_williams_%_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_osc_adx_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_osc_ao_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_osc_cci_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_osc_macd_crossover_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_osc_trix_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_osc_uo_bin": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_rat_alpha_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "m_rat_ror_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "m_rat_win_rate_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "m_tvv_cmf": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "m_tvv_obv_1d_binary": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_common_sense_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_information_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_sharpe_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_sortino_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_teynor_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "v_rat_win_loss_bin": {
#                     "dataType": "double precision",
#                     "null_count": 1,
#                     "non_null_count": 199,
#                     "total_rows": 200,
#                     "null_ratio": 0.005,
#                     "risk_classification": "LOW"
#                 },
#                 "bullish": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "bearish": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "neutral": {
#                     "dataType": "bigint",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 35,
#             "total_rows": 200,
#             "first_timestamp": "2025-03-03 05:59:59+00:00",
#             "last_timestamp": null,
#             "timestamp_status": "WARNING: First and/or Last timestamp is NULL",
#             "duplicate_count": 0,
#             "duplicate_status": "VALID"
#         },
#         "FE_DMV_SCORES": {
#             "columns": {
#                 "slug": {
#                     "dataType": "text",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Durability_Score": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Momentum_Score": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 },
#                 "Valuation_Score": {
#                     "dataType": "double precision",
#                     "null_count": 0,
#                     "non_null_count": 200,
#                     "total_rows": 200,
#                     "null_ratio": 0.0,
#                     "risk_classification": "LOW"
#                 }
#             },
#             "column_count": 4,
#             "total_rows": 200,
#             "first_timestamp": null,
#             "last_timestamp": null,
#             "timestamp_status": "VALID",
#             "duplicate_count": null,
#             "duplicate_status": "VALID"
#         }
#     }
# }

# %%
# @title GenAI
import os
import json
import logging
from dotenv import load_dotenv
import google.generativeai as genai

# Load environment variables
load_dotenv()

# Securely fetch API Key from .env
API_KEY = os.getenv("GEMINI_API_KEY")

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# Ensure API key is available
if not API_KEY:
    logger.error("GEMINI_API_KEY is missing. Please set it in the .env file.")
    exit(1)

# Configure Gemini API
genai.configure(api_key=API_KEY)

# Model generation configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

# Load the database analysis results
try:
    with open("database_analysis_results.json", "r") as f:
        analysis_results = json.load(f)
    logger.info("Loaded database analysis results successfully.")
except FileNotFoundError:
    logger.error("Database analysis results file not found.")
    exit(1)
except json.JSONDecodeError as e:
    logger.error(f"Error decoding JSON file: {e}")
    exit(1)

def summarize_analysis(analysis_data: dict, model: genai.GenerativeModel) -> str:
    """Summarizes database analysis results using the Gemini API."""

    # Convert analysis data to JSON string (limit size to avoid API request issues)
    analysis_json_str = json.dumps(analysis_data, indent=4)[:128000]  # Trim if too large

    system_prompt = """
                      You are a super-efficient data quality analyst generating summaries for Telegram.
                      Analyze the provided JSON database analysis report. Deliver actionable insights
                      about any data quality issues. Highlighting and recommending fixes for any immediate needs.

                      ### **Knowledge Base (What Each Data Point Means)**
                      - **Null Ratio:** Indicates missing values in a column.
                        - Below **0.2** → Low risk ✅
                        - **0.2 to 0.49** → Medium risk ⚠️
                        - **0.49 to 0.89** → High risk 🔴
                        - **Above 0.89** → **CRITICAL - Requires immediate action**

                      - **Duplicate Count:** If greater than 0, it means there are duplicate values in a critical column.
                        - Duplicate timestamps can **cause incorrect aggregations & signal misfires**.
                        - Duplicate `slug + timestamp` values → **CRITICAL ERROR - Requires immediate action**
                        - Missing timestamps → **High-risk issue

                      - **Timestamp Validation:** Ensures time-based data consistency.
                        - FE_RATIOS, FE_MOMENTUM, FE_MOMENTUM_SIGNALS, FE_OSCILLATOR, FE_OSCILLATORS_SIGNALS, FE_RATIOS_SIGNALS, FE_TVV, FE_TVV_SIGNALS, FE_PCT_CHANGE should have the same first and last timestamp
                        - Other tables **must have at least a 4-day gap** between timestamps.
                        - Missing timestamps → **High-risk issue**

                      ### **Filtering & Summary Guidelines**
                      - ❌ **Do NOT include normal or low-risk findings**.
                      - ✅ **Report ONLY high-risk, critical, or failed checks**.
                      - 📌 **Highlight specific tables and columns with issues**.
                      - 🔍 **Provide clear explanations and recommendations**.

                      Format your response as a well formatted and spaced paragraph **technical summary for a Telegram notification**:
                     --------
                      QA Alert (1/n) (DatabaseName)

                      Issue: (Brief problem description)

                      Table: (Affected Table)

                      Details: (1-2 sentences explaining the issue and impact)

                      Action: (1 sentence recommendation)
                      """



    user_prompt = f"""
              Analyze the following database analysis results and extract **ONLY high-risk, failed, or critical issues**
              Make sure the output is presentation ready .. no header footer ... no nonsense text only what is important.
              ```json
              {analysis_json_str}

                  ```
                  """

    try:
        response = model.generate_content(system_prompt + user_prompt)
        return response.text if response else "No summary generated."

    except genai.exceptions.APIException as e:
        logger.error(f"Error generating summary: {e}")
        return "Error: Failed to generate summary."

# Create a Gemini model instance
model = genai.GenerativeModel(model_name="gemini-2.0-flash-exp", generation_config=generation_config)

# Summarize the analysis results
summary = summarize_analysis(analysis_results, model)

# Print or log summary
if summary:
    logger.info("Database analysis summary generated successfully.")
    print("Summary of Database Analysis:\n")
    print(summary)
else:
    logger.warning("No summary generated.")
# Out:
# Summary of Database Analysis:
#
# ```text
# QA Alert (1/2) (cp_ai)
#
# Issue: Critical Null Ratio in tvl column
#
# Table: crypto_listings_latest
#
# Details: The `tvl` column has a null ratio of 0.9277, indicating that over 92% of the values are missing, which can significantly impact analysis.
# Action: Investigate data source and implement a strategy to fill or handle these missing values.
#
# QA Alert (2/2) (cp_ai)
#
# Issue: Missing Timestamp Data
#
# Table: FE_DMV_ALL
#
# Details: The last timestamp field is null for the table FE_DMV_ALL, potentially leading to issues with time-series analysis.
# Action: Review data ingestion and transformation logic to ensure timestamp data is captured, and ensure that the correct timestamp fields are used.
# ```

# %%
# @title Telegram Runner
import requests

def send_telegram_message(bot_token, chat_id, message):
    """Sends a message to a Telegram chat using the provided bot token.

    Args:
        bot_token: Your Telegram bot token.
        chat_id: The ID of the Telegram chat.
        message: The message to send.
    """

    try:
        url = f"https://api.telegram.org/bot{bot_token}/sendMessage"
        params = {
            "chat_id": chat_id,
            "text": message
        }
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)
        print("Message sent successfully.")
    except requests.exceptions.RequestException as e:
        print(f"Error sending message: {e}")

# Example usage:
bot_token = "7911188723:AAFB1_XTNd_1kDNhvqfhm6C0gL34HE8P8fU"  # Replace with your bot token
chat_id = "-4708531708"  # Replace with your chat ID
message = summary

send_telegram_message(bot_token, chat_id, message)
# Out:
# Message sent successfully.
